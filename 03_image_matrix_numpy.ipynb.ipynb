# %% [raw]
# # Image Matrix using NumPy
#
# This notebook explains how images can be represented as matrices/arrays.
#
# ## Topics Covered
#
# - Image as matrix
# - Pixel values
# - 2D arrays
# - NumPy array representation
# - Basic image matrix understanding
#
# ## Purpose
#
# I created this notebook to understand how images are stored and processed using matrices in Python.

# %%
import numpy as np         # array

# %%
import matplotlib.pyplot as plt   # visiulization

# %%
from PIL import Image  # python image libarry

# %%
feature_image = Image.open(r"C:\Users\vp551_h9usjvj\Downloads\horse image.jpg")
feature_image.show()

# %%
feature_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=525x350>

# %%
print(type(feature_image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
fea_arr = np.asarray(feature_image)
fea_arr
# Out:
# array([[[ 54,  69,  72],
#         [ 54,  69,  72],
#         [ 54,  69,  72],
#         ...,
#         [231, 200, 171],
#         [236, 202, 174],
#         [238, 204, 176]],
#
#        [[ 54,  69,  72],
#         [ 54,  69,  72],
#         [ 55,  70,  73],
#         ...,
#         [235, 204, 175],
#         [238, 204, 176],
#         [239, 205, 177]],
#
#        [[ 54,  69,  72],
#         [ 55,  70,  73],
#         [ 55,  70,  73],
#         ...,
#         [238, 207, 178],
#         [239, 208, 179],
#         [241, 207, 179]],
#
#        ...,
#
#        [[ 75,  43,  32],
#         [ 80,  48,  37],
#         [ 84,  52,  41],
#         ...,
#         [143,  95,  59],
#         [143,  95,  59],
#         [143,  95,  59]],
#
#        [[ 77,  44,  35],
#         [ 82,  49,  40],
#         [ 85,  53,  42],
#         ...,
#         [140,  92,  56],
#         [140,  92,  56],
#         [141,  93,  57]],
#
#        [[ 82,  49,  40],
#         [ 85,  52,  43],
#         [ 87,  55,  44],
# ...

# %%
plt.imshow(fea_arr)
plt.show()

# %%
fea_arr.shape
# Out:
# (350, 525, 3)
